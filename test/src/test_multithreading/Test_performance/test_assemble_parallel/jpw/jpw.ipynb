# %%
import numpy as np
import matplotlib.pyplot as plt
from collections.abc import Iterable
from matplotlib.patches import Patch  # Per creare elementi di legenda personalizzati

# %% [markdown]
# ## effetto di avere piu job per worker in solo Calcolo triple (compilato con cronometro solo in calcolo triple)

# %% [markdown]
# compila con il cronometro in fe_bilinear_form_assembler
#
# auto start = std::chrono::high_resolution_clock::now();
#
# auto end = std::chrono::high_resolution_clock::now();
# auto duration = std::chrono::duration_cast<std::chrono::microseconds>(end - start);
# std::cout<<duration.count()<<",";

# %%
def boxplot_unionevettori(data_par_for_n,title):
    fig, ax = plt.subplots(figsize=[10, 8])
    
    boxs = []
    ticks = []
    for i in range(len(data_par_for_n)):
        boxs.append(data_par_for_n[i])
        ticks.append(str(jpw[i]))

    
    bplot = ax.boxplot(boxs, showfliers=False, patch_artist=True)

    ax.set(xlabel = 'job per worker',ylabel = 'Microseconds')
    ax.set_title( title, loc = 'left')
    ax.set_xticks(range(1,1+len(boxs)),ticks)

    plt.figtext(0.63, 0.9, f"threadpool: size_queue({size_queue}), worker({n_threads})\nnodi : {nodi}\nruns: {len(data_par_for_n[0])}", fontsize=9, 
            bbox=dict(facecolor='white', edgecolor='black'))

# %% [markdown]
# nodi300 thread 3 (1,5,10,50)
# nodi500 thread 3 (1,10,50)
# nodi1000 thread 3 (1,10,50)
#
# nodi300 thread 7 (1,5,10,50)
# nodi500 thread 7 (1,10,50)
# nodi1000 thread 7 (1,10,50)

# %%
#set parameter
nodi = 1000 #costo singola iterazione
n_threads = 7
size_queue = 1000 #hardcome in codice ma qui non conta
jpw = [1,10,50] # n_job = kk*num_worker (+1)

# %%
# !./run_assemble_unicovettore_parallel.sh 100 2 10

# %%
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])

# %%
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %% [markdown]
# 3 thread

# %%
n_threads = 3

# %%
nodi = 300 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %%
nodi = 500 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %%
nodi = 1000 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %% [markdown]
# 7 thread

# %%
n_threads = 7

# %%
nodi = 300 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %%
nodi = 500 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %%
nodi = 1000 
dati_assemble_parallel = []
for i,nb in enumerate(jpw):
    dati_assemble_parallel.append(np.genfromtxt("test_assemble_unicovettore_nodi"+str(nodi)+"_thread"+str(n_threads)+"_jpw"+str(nb)+".txt",delimiter=',',dtype=int)[:-1])
boxplot_unionevettori(dati_assemble_parallel,"effetto di capillarità dei job in calcolo triple in assemble ")

# %% [markdown]
# /mnt/c/Users/Cosimo Solidoro/Desktop/ProgettoPacs/plot/plot_assemble/calcolo_triple_assemble3/boxplot_calcolotriple_OptO3_assemble3_nodi500
