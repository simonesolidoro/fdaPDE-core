# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# relax

# %%
# !make
# Out:
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_pop_back.cpp -o test_deque_pop_back
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_pop_back_multi.cpp -o test_deque_pop_back_multi
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_pop_front.cpp -o test_deque_pop_front
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_pop_front_multi.cpp -o test_deque_pop_front_multi
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_push_back.cpp -o test_deque_push_back
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_push_back_multi.cpp -o test_deque_push_back_multi
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_push_front.cpp -o test_deque_push_front
# g++  -std=c++20 -pthread -Wall -I../../../../  test_deque_push_front_multi.cpp -o test_deque_push_front_multi
# g++  -std=c++20 -pthread -Wall -I../../../../  test_worker_queue_pop_back.cpp -o test_worker_queue_pop_back
# ...

# %% [markdown]
# # Single threaded tests

# %% [markdown]
# ## Pop back

# %%
# !sh risultati.sh "test_deque_pop_back" 200 16000
# !sh risultati.sh "test_worker_queue_pop_back" 200 16000

test_worker_queue_pop_back = np.genfromtxt("test_worker_queue_pop_back.txt",delimiter=',',dtype=int)[:-1]
test_deque_pop_back = np.genfromtxt("test_deque_pop_back.txt",delimiter=',',dtype=int)[:-1]

fig, ax = plt.subplots()

ax.boxplot([test_deque_pop_back,test_worker_queue_pop_back], positions=[1,2])
# Etichette per gli assi
ax.set_xticks([1,2],["Deque","Worker_queue"])
ax.set(ylabel = 'Microseconds')
ax.set(title = 'Single threaded pop_back() of 16000 elements')

plt.show()

# %% [markdown]
# ## Pop front

# %%
# !sh risultati.sh "test_deque_pop_front" 200 16000
# !sh risultati.sh "test_worker_queue_pop_front" 200 16000

test_worker_queue_pop_front = np.genfromtxt("test_worker_queue_pop_front.txt",delimiter=',',dtype=int)[:-1]
test_deque_pop_front = np.genfromtxt("test_deque_pop_front.txt",delimiter=',',dtype=int)[:-1]

fig, ax = plt.subplots()

ax.boxplot([test_deque_pop_front,test_worker_queue_pop_front], positions=[1,2])
# Etichette per gli assi
ax.set_xticks([1,2],["Deque","Worker_queue"])
ax.set(ylabel = 'Microseconds')
ax.set(title = 'Single threaded pop_front() of 16000 elements')

plt.show()

# %% [markdown]
# ## Push back

# %%
# !sh risultati.sh "test_deque_push_back" 200 16000
# !sh risultati.sh "test_worker_queue_push_back" 200 16000

test_worker_queue_push_back = np.genfromtxt("test_worker_queue_push_back.txt",delimiter=',',dtype=int)[:-1]
test_deque_push_back = np.genfromtxt("test_deque_push_back.txt",delimiter=',',dtype=int)[:-1]

fig, ax = plt.subplots()

ax.boxplot([test_deque_push_back,test_worker_queue_push_back], positions=[1,2])
# Etichette per gli assi
ax.set_xticks([1,2],["Deque","Worker_queue"])
ax.set(ylabel = 'Microseconds')
ax.set(title = 'Single threaded push_back() of 16000 elements')

plt.show()

# %% [markdown]
# ## Push front

# %%
# !sh risultati.sh "test_deque_push_front" 200 16000
# !sh risultati.sh "test_worker_queue_push_front" 200 16000

test_worker_queue_push_front = np.genfromtxt("test_worker_queue_push_front.txt",delimiter=',',dtype=int)[:-1]
test_deque_push_front = np.genfromtxt("test_deque_push_front.txt",delimiter=',',dtype=int)[:-1]

fig, ax = plt.subplots()

ax.boxplot([test_deque_push_front,test_worker_queue_push_front], positions=[1,2])
# Etichette per gli assi
ax.set_xticks([1,2],["Deque","Worker_queue"])
ax.set(ylabel = 'Microseconds')
ax.set(title = 'Single threaded push_front() of 16000 elements')

plt.show()

# %% [markdown]
# # Multithreaded tests

# %% [markdown]
# ## Pop back

# %%
test_worker_queue = []
test_deque = []

# !sh risultati.sh "test_deque_pop_back_multi" 200 16000 2
# !sh risultati.sh "test_worker_queue_pop_back_multi" 200 16000 2

test_deque.append(np.genfromtxt("test_deque_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_back_multi" 200 16000 4
# !sh risultati.sh "test_worker_queue_pop_back_multi" 200 16000 4

test_deque.append(np.genfromtxt("test_deque_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_back_multi" 200 16000 6
# !sh risultati.sh "test_worker_queue_pop_back_multi" 200 16000 6

test_deque.append(np.genfromtxt("test_deque_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_back_multi" 200 16000 8
# !sh risultati.sh "test_worker_queue_pop_back_multi" 200 16000 8

test_deque.append(np.genfromtxt("test_deque_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_back_multi.txt",delimiter=',',dtype=int)[:-1])

# %%
fig, ax = plt.subplots(1,2,figsize=[10, 5])

ax[0].boxplot(test_deque)
# Etichette per gli assi
ax[0].set_xticks([1,2,3,4],["2","4","6","8"])
ax[0].set(ylabel = 'Microseconds')
ax[0].set(title = 'Multithreaded pop_back into deque')

ax[1].boxplot(test_worker_queue)
# Etichette per gli assi
ax[1].set_xticks([1,2,3,4],["2","4","6","8"])
ax[1].set(ylabel = 'Microseconds')
ax[1].set(title = 'Multithreaded pop_back into worker_queue')

plt.show()

# %% [markdown]
# ## Pop front

# %%
test_worker_queue = []
test_deque = []

# !sh risultati.sh "test_deque_pop_front_multi" 200 16000 2
# !sh risultati.sh "test_worker_queue_pop_front_multi" 200 16000 2

test_deque.append(np.genfromtxt("test_deque_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_front_multi" 200 16000 4
# !sh risultati.sh "test_worker_queue_pop_front_multi" 200 16000 4

test_deque.append(np.genfromtxt("test_deque_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_front_multi" 200 16000 6
# !sh risultati.sh "test_worker_queue_pop_front_multi" 200 16000 6

test_deque.append(np.genfromtxt("test_deque_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_pop_front_multi" 200 16000 8
# !sh risultati.sh "test_worker_queue_pop_front_multi" 200 16000 8

test_deque.append(np.genfromtxt("test_deque_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_pop_front_multi.txt",delimiter=',',dtype=int)[:-1])

# %%
fig, ax = plt.subplots(1,2,figsize=[10, 5])

ax[0].boxplot(test_deque)
# Etichette per gli assi
ax[0].set_xticks([1,2,3,4],["2","4","6","8"])
ax[0].set(ylabel = 'Microseconds')
ax[0].set(title = 'Multithreaded pop_front into deque')

ax[1].boxplot(test_worker_queue)
# Etichette per gli assi
ax[1].set_xticks([1,2,3,4],["2","4","6","8"])
ax[1].set(ylabel = 'Microseconds')
ax[1].set(title = 'Multithreaded pop_front into worker_queue')

plt.show()

# %% [markdown]
# ## Push back

# %%
test_worker_queue = []
test_deque = []

# !sh risultati.sh "test_deque_push_back_multi" 200 16000 2
# !sh risultati.sh "test_worker_queue_push_back_multi" 200 16000 2

test_deque.append(np.genfromtxt("test_deque_push_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_back_multi" 200 16000 4
# !sh risultati.sh "test_worker_queue_push_back_multi" 200 16000 4

test_deque.append(np.genfromtxt("test_deque_push_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_back_multi" 200 16000 6
# !sh risultati.sh "test_worker_queue_push_back_multi" 200 16000 6

test_deque.append(np.genfromtxt("test_deque_push_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_back_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_back_multi" 200 16000 8
# !sh risultati.sh "test_worker_queue_push_back_multi" 200 16000 8

test_deque.append(np.genfromtxt("test_deque_push_back_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_back_multi.txt",delimiter=',',dtype=int)[:-1])

# %%
fig, ax = plt.subplots(1,2,figsize=[10, 5])

ax[0].boxplot(test_deque)
# Etichette per gli assi
ax[0].set_xticks([1,2,3,4],["2","4","6","8"])
ax[0].set(ylabel = 'Microseconds')
ax[0].set(title = 'Multithreaded push_back into deque')

ax[1].boxplot(test_worker_queue)
# Etichette per gli assi
ax[1].set_xticks([1,2,3,4],["2","4","6","8"])
ax[1].set(ylabel = 'Microseconds')
ax[1].set(title = 'Multithreaded push_back into worker_queue')

plt.show()

# %% [markdown]
# ## Push front

# %%
test_worker_queue = []
test_deque = []

# !sh risultati.sh "test_deque_push_front_multi" 200 16000 2
# !sh risultati.sh "test_worker_queue_push_front_multi" 200 16000 2

test_deque.append(np.genfromtxt("test_deque_push_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_front_multi" 200 16000 4
# !sh risultati.sh "test_worker_queue_push_front_multi" 200 16000 4

test_deque.append(np.genfromtxt("test_deque_push_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_front_multi" 200 16000 6
# !sh risultati.sh "test_worker_queue_push_front_multi" 200 16000 6

test_deque.append(np.genfromtxt("test_deque_push_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_front_multi.txt",delimiter=',',dtype=int)[:-1])

# !sh risultati.sh "test_deque_push_front_multi" 200 16000 8
# !sh risultati.sh "test_worker_queue_push_front_multi" 200 16000 8

test_deque.append(np.genfromtxt("test_deque_push_front_multi.txt",delimiter=',',dtype=int)[:-1])
test_worker_queue.append(np.genfromtxt("test_worker_queue_push_front_multi.txt",delimiter=',',dtype=int)[:-1])

# %%
fig, ax = plt.subplots(1,2,figsize=[10, 5])

ax[0].boxplot(test_deque)
# Etichette per gli assi
ax[0].set_xticks([1,2,3,4],["2","4","6","8"])
ax[0].set(ylabel = 'Microseconds')
ax[0].set(title = 'Multithreaded push_front into deque')

ax[1].boxplot(test_worker_queue)
# Etichette per gli assi
ax[1].set_xticks([1,2,3,4],["2","4","6","8"])
ax[1].set(ylabel = 'Microseconds')
ax[1].set(title = 'Multithreaded push_front into worker_queue')

plt.show()
